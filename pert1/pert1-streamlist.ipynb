# %%
# !pip install streamlit --verbose
# Out:
# Using pip 22.3.1 from C:\ANDREW_DATA\Python-Web-Programming\pert1\venv\Lib\site-packages\pip (python 3.11)
#   Link requires a different Python (3.11.1 not in: '<3.5'): https://files.pythonhosted.org/packages/57/3c/3435b11cea87499c4cd35c17420dd9232c3dfc951d6f772ab97698d158c7/streamlit-0.55.2-py2.py3-none-any.whl (from https://pypi.org/simple/streamlit/) (requires-python:<3.5)
# Collecting streamlit
#   Using cached streamlit-1.17.0-py2.py3-none-any.whl (9.3 MB)
# Collecting altair>=3.2.0
#   Using cached altair-4.2.1-py3-none-any.whl (813 kB)
# Requirement already satisfied: blinker>=1.0.0 in c:\andrew_data\python-web-programming\pert1\venv\lib\site-packages (from streamlit) (1.5)
# Requirement already satisfied: cachetools>=4.0 in c:\andrew_data\python-web-programming\pert1\venv\lib\site-packages (from streamlit) (5.3.0)
# Requirement already satisfied: click>=7.0 in c:\andrew_data\python-web-programming\pert1\venv\lib\site-packages (from streamlit) (8.1.3)
# Collecting importlib-metadata>=1.4
#   Using cached importlib_metadata-6.0.0-py3-none-any.whl (21 kB)
# Requirement already satisfied: numpy in c:\andrew_data\python-web-programming\pert1\venv\lib\site-packages (from streamlit) (1.24.1)
# Requirement already satisfied: packaging>=14.1 in c:\andrew_data\python-web-programming\pert1\venv\lib\site-packages (from streamlit) (23.0)
# Requirement already satisfied: pandas>=0.21.0 in c:\andrew_data\python-web-programming\pert1\venv\lib\site-packages (from streamlit) (1.5.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\andrew_data\python-web-programming\pert1\venv\lib\site-packages (from streamlit) (9.4.0)
# Requirement already satisfied: protobuf<4,>=3.12 in c:\andrew_data\python-web-programming\pert1\venv\lib\site-packages (from streamlit) (3.20.3)
# Requirement already satisfied: pyarrow>=4.0 in c:\andrew_data\python-web-programming\pert1\venv\lib\site-packages (from streamlit) (10.0.1)
# Requirement already satisfied: pympler>=0.9 in c:\andrew_data\python-web-programming\pert1\venv\lib\site-packages (from streamlit) (1.0.1)
# Requirement already satisfied: python-dateutil in c:\andrew_data\python-web-programming\pert1\venv\lib\site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: requests>=2.4 in c:\andrew_data\python-web-programming\pert1\venv\lib\site-packages (from streamlit) (2.28.2)
# Collecting rich>=10.11.0
#   Using cached rich-13.2.0-py3-none-any.whl (238 kB)
# Requirement already satisfied: semver in c:\andrew_data\python-web-programming\pert1\venv\lib\site-packages (from streamlit) (2.13.0)
# Requirement already satisfied: toml in c:\andrew_data\python-web-programming\pert1\venv\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in c:\andrew_data\python-web-programming\pert1\venv\lib\site-packages (from streamlit) (4.4.0)
# Collecting tzlocal>=1.1
#   Using cached tzlocal-4.2-py3-none-any.whl (19 kB)
# Requirement already satisfied: validators>=0.2 in c:\andrew_data\python-web-programming\pert1\venv\lib\site-packages (from streamlit) (0.20.0)
# Collecting gitpython!=3.1.19
#   Using cached GitPython-3.1.30-py3-none-any.whl (184 kB)
# Requirement already satisfied: pydeck>=0.1.dev5 in c:\andrew_data\python-web-programming\pert1\venv\lib\site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: tornado>=5.0 in c:\andrew_data\python-web-programming\pert1\venv\lib\site-packages (from streamlit) (6.2)
# Requirement already satisfied: watchdog in c:\andrew_data\python-web-programming\pert1\venv\lib\site-packages (from streamlit) (2.2.1)
# Requirement already satisfied: entrypoints in c:\andrew_data\python-web-programming\pert1\venv\lib\site-packages (from altair>=3.2.0->streamlit) (0.4)
# Requirement already satisfied: jinja2 in c:\andrew_data\python-web-programming\pert1\venv\lib\site-packages (from altair>=3.2.0->streamlit) (3.1.2)
# Collecting jsonschema>=3.0
#   Using cached jsonschema-4.17.3-py3-none-any.whl (90 kB)
# Requirement already satisfied: toolz in c:\andrew_data\python-web-programming\pert1\venv\lib\site-packages (from altair>=3.2.0->streamlit) (0.12.0)
# Requirement already satisfied: colorama in c:\andrew_data\python-web-programming\pert1\venv\lib\site-packages (from click>=7.0->streamlit) (0.4.6)
# Collecting gitdb<5,>=4.0.1
#   Using cached gitdb-4.0.10-py3-none-any.whl (62 kB)
# Requirement already satisfied: zipp>=0.5 in c:\andrew_data\python-web-programming\pert1\venv\lib\site-packages (from importlib-metadata>=1.4->streamlit) (3.11.0)
# Requirement already satisfied: pytz>=2020.1 in c:\andrew_data\python-web-programming\pert1\venv\lib\site-packages (from pandas>=0.21.0->streamlit) (2022.7.1)
# Requirement already satisfied: six>=1.5 in c:\andrew_data\python-web-programming\pert1\venv\lib\site-packages (from python-dateutil->streamlit) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\andrew_data\python-web-programming\pert1\venv\lib\site-packages (from requests>=2.4->streamlit) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\andrew_data\python-web-programming\pert1\venv\lib\site-packages (from requests>=2.4->streamlit) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\andrew_data\python-web-programming\pert1\venv\lib\site-packages (from requests>=2.4->streamlit) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\andrew_data\python-web-programming\pert1\venv\lib\site-packages (from requests>=2.4->streamlit) (2022.12.7)
# Collecting markdown-it-py<3.0.0,>=2.1.0
#   Using cached markdown_it_py-2.1.0-py3-none-any.whl (84 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in c:\andrew_data\python-web-programming\pert1\venv\lib\site-packages (from rich>=10.11.0->streamlit) (2.14.0)
# Requirement already satisfied: pytz-deprecation-shim in c:\andrew_data\python-web-programming\pert1\venv\lib\site-packages (from tzlocal>=1.1->streamlit) (0.1.0.post0)
# Requirement already satisfied: tzdata in c:\andrew_data\python-web-programming\pert1\venv\lib\site-packages (from tzlocal>=1.1->streamlit) (2022.7)
# Requirement already satisfied: decorator>=3.4.0 in c:\andrew_data\python-web-programming\pert1\venv\lib\site-packages (from validators>=0.2->streamlit) (5.1.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\andrew_data\python-web-programming\pert1\venv\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit) (5.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\andrew_data\python-web-programming\pert1\venv\lib\site-packages (from jinja2->altair>=3.2.0->streamlit) (2.1.2)
# Requirement already satisfied: attrs>=17.4.0 in c:\andrew_data\python-web-programming\pert1\venv\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (22.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\andrew_data\python-web-programming\pert1\venv\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (0.19.3)
# Requirement already satisfied: mdurl~=0.1 in c:\andrew_data\python-web-programming\pert1\venv\lib\site-packages (from markdown-it-py<3.0.0,>=2.1.0->rich>=10.11.0->streamlit) (0.1.2)
# Installing collected packages: markdown-it-py, jsonschema, importlib-metadata, gitdb, tzlocal, rich, gitpython, altair, streamlit
# ERROR: Could not install packages due to an OSError.
# Check the permissions.
# Traceback (most recent call last):
#   File "C:\ANDREW_DATA\Python-Web-Programming\pert1\venv\Lib\site-packages\pip\_internal\commands\install.py", line 494, in run
#     installed = install_given_reqs(
#                 ^^^^^^^^^^^^^^^^^^^
#   File "C:\ANDREW_DATA\Python-Web-Programming\pert1\venv\Lib\site-packages\pip\_internal\req\__init__.py", line 73, in install_given_reqs
#     requirement.install(
#   File "C:\ANDREW_DATA\Python-Web-Programming\pert1\venv\Lib\site-packages\pip\_internal\req\req_install.py", line 792, in install
#     install_wheel(
#   File "C:\ANDREW_DATA\Python-Web-Programming\pert1\venv\Lib\site-packages\pip\_internal\operations\install\wheel.py", line 729, in install_wheel
#     _install_wheel(
#   File "C:\ANDREW_DATA\Python-Web-Programming\pert1\venv\Lib\site-packages\pip\_internal\operations\install\wheel.py", line 589, in _install_wheel
#     file.save()
#   File "C:\ANDREW_DATA\Python-Web-Programming\pert1\venv\Lib\site-packages\pip\_internal\operations\install\wheel.py", line 382, in save
#     os.unlink(self.dest_path)
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\ANDREW_DATA\\Python-Web-Programming\\pert1\\venv\\Lib\\site-packages\\altair\\examples\\trellis_histogram.py'
# Collecting streamlit
#   Downloading streamlit-1.17.0-py2.py3-none-any.whl (9.3 MB)
#      ---------------------------------------- 9.3/9.3 MB 1.6 MB/s eta 0:00:00
# Collecting altair>=3.2.0
#   Downloading altair-4.2.1-py3-none-any.whl (813 kB)
#      -------------------------------------- 813.6/813.6 kB 1.0 MB/s eta 0:00:00
# Collecting blinker>=1.0.0
#   Downloading blinker-1.5-py2.py3-none-any.whl (12 kB)
# Collecting cachetools>=4.0
#   Downloading cachetools-5.3.0-py3-none-any.whl (9.3 kB)
# Requirement already satisfied: click>=7.0 in c:\andrew_data\python-web-programming\pert1\venv\lib\site-packages (from streamlit) (8.1.3)
# Collecting importlib-metadata>=1.4
#   Downloading importlib_metadata-6.0.0-py3-none-any.whl (21 kB)
# Collecting numpy
#   Downloading numpy-1.24.1-cp311-cp311-win_amd64.whl (14.8 MB)
#      ---------------------------------------- 14.8/14.8 MB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=14.1 in c:\andrew_data\python-web-programming\pert1\venv\lib\site-packages (from streamlit) (23.0)
# Collecting pandas>=0.21.0
#   Downloading pandas-1.5.3-cp311-cp311-win_amd64.whl (10.3 MB)
#      ---------------------------------------- 10.3/10.3 MB 1.3 MB/s eta 0:00:00
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.4.0-cp311-cp311-win_amd64.whl (2.5 MB)
#      ---------------------------------------- 2.5/2.5 MB 1.3 MB/s eta 0:00:00
# Collecting protobuf<4,>=3.12
#   Downloading protobuf-3.20.3-py2.py3-none-any.whl (162 kB)
#      -------------------------------------- 162.1/162.1 kB 1.9 MB/s eta 0:00:00
# Collecting pyarrow>=4.0
#   Downloading pyarrow-10.0.1-cp311-cp311-win_amd64.whl (20.2 MB)
#      -------------------------------------- 20.2/20.2 MB 896.1 kB/s eta 0:00:00
# Collecting pympler>=0.9
#   Downloading Pympler-1.0.1-py3-none-any.whl (164 kB)
#      -------------------------------------- 164.8/164.8 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil in c:\andrew_data\python-web-programming\pert1\venv\lib\site-packages (from streamlit) (2.8.2)
# Collecting requests>=2.4
#   Downloading requests-2.28.2-py3-none-any.whl (62 kB)
#      ---------------------------------------- 62.8/62.8 kB 1.6 MB/s eta 0:00:00
# Collecting rich>=10.11.0
#   Downloading rich-13.2.0-py3-none-any.whl (238 kB)
#      -------------------------------------- 238.9/238.9 kB 3.7 MB/s eta 0:00:00
# Collecting semver
#   Downloading semver-2.13.0-py2.py3-none-any.whl (12 kB)
# Collecting toml
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Collecting typing-extensions>=3.10.0.0
#   Downloading typing_extensions-4.4.0-py3-none-any.whl (26 kB)
# Collecting tzlocal>=1.1
#   Downloading tzlocal-4.2-py3-none-any.whl (19 kB)
# Collecting validators>=0.2
#   Downloading validators-0.20.0.tar.gz (30 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting gitpython!=3.1.19
#   Downloading GitPython-3.1.30-py3-none-any.whl (184 kB)
#      -------------------------------------- 184.0/184.0 kB 1.8 MB/s eta 0:00:00
# Collecting pydeck>=0.1.dev5
#   Downloading pydeck-0.8.0-py2.py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 243.8 kB/s eta 0:00:00
# Requirement already satisfied: tornado>=5.0 in c:\andrew_data\python-web-programming\pert1\venv\lib\site-packages (from streamlit) (6.2)
# Collecting watchdog
#   Downloading watchdog-2.2.1-py3-none-win_amd64.whl (78 kB)
#      -------------------------------------- 79.0/79.0 kB 100.0 kB/s eta 0:00:00
# Collecting entrypoints
#   Downloading entrypoints-0.4-py3-none-any.whl (5.3 kB)
# Requirement already satisfied: jinja2 in c:\andrew_data\python-web-programming\pert1\venv\lib\site-packages (from altair>=3.2.0->streamlit) (3.1.2)
# Collecting jsonschema>=3.0
#   Downloading jsonschema-4.17.3-py3-none-any.whl (90 kB)
#      -------------------------------------- 90.4/90.4 kB 568.4 kB/s eta 0:00:00
# Collecting toolz
#   Downloading toolz-0.12.0-py3-none-any.whl (55 kB)
#      -------------------------------------- 55.8/55.8 kB 485.1 kB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\andrew_data\python-web-programming\pert1\venv\lib\site-packages (from click>=7.0->streamlit) (0.4.6)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      -------------------------------------- 62.7/62.7 kB 846.7 kB/s eta 0:00:00
# Collecting zipp>=0.5
#   Downloading zipp-3.11.0-py3-none-any.whl (6.6 kB)
# Collecting pytz>=2020.1
#   Downloading pytz-2022.7.1-py2.py3-none-any.whl (499 kB)
#      -------------------------------------- 499.4/499.4 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in c:\andrew_data\python-web-programming\pert1\venv\lib\site-packages (from python-dateutil->streamlit) (1.16.0)
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.0.1-cp311-cp311-win_amd64.whl (96 kB)
#      -------------------------------------- 96.0/96.0 kB 686.4 kB/s eta 0:00:00
# Collecting idna<4,>=2.5
#   Downloading idna-3.4-py3-none-any.whl (61 kB)
#      -------------------------------------- 61.5/61.5 kB 827.4 kB/s eta 0:00:00
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.14-py2.py3-none-any.whl (140 kB)
#      -------------------------------------- 140.6/140.6 kB 1.0 MB/s eta 0:00:00
# Collecting certifi>=2017.4.17
#   Downloading certifi-2022.12.7-py3-none-any.whl (155 kB)
#      -------------------------------------- 155.3/155.3 kB 1.0 MB/s eta 0:00:00
# Collecting markdown-it-py<3.0.0,>=2.1.0
#   Downloading markdown_it_py-2.1.0-py3-none-any.whl (84 kB)
#      -------------------------------------- 84.5/84.5 kB 952.6 kB/s eta 0:00:00
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in c:\andrew_data\python-web-programming\pert1\venv\lib\site-packages (from rich>=10.11.0->streamlit) (2.14.0)
# Collecting pytz-deprecation-shim
#   Downloading pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl (15 kB)
# Collecting tzdata
#   Downloading tzdata-2022.7-py2.py3-none-any.whl (340 kB)
#      -------------------------------------- 340.1/340.1 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: decorator>=3.4.0 in c:\andrew_data\python-web-programming\pert1\venv\lib\site-packages (from validators>=0.2->streamlit) (5.1.1)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\andrew_data\python-web-programming\pert1\venv\lib\site-packages (from jinja2->altair>=3.2.0->streamlit) (2.1.2)
# Collecting attrs>=17.4.0
#   Downloading attrs-22.2.0-py3-none-any.whl (60 kB)
#      -------------------------------------- 60.0/60.0 kB 802.9 kB/s eta 0:00:00
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0
#   Downloading pyrsistent-0.19.3-cp311-cp311-win_amd64.whl (62 kB)
#      -------------------------------------- 62.7/62.7 kB 832.9 kB/s eta 0:00:00
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: pytz, charset-normalizer, zipp, watchdog, validators, urllib3, tzdata, typing-extensions, toolz, toml, smmap, semver, pyrsistent, pympler, protobuf, pillow, numpy, mdurl, idna, entrypoints, certifi, cachetools, blinker, attrs, requests, pytz-deprecation-shim, pydeck, pyarrow, pandas, markdown-it-py, jsonschema, importlib-metadata, gitdb, tzlocal, rich, gitpython, altair, streamlit
#   Running setup.py install for validators: started
#   Running setup.py install for validators: finished with status 'done'
# Successfully installed altair-4.2.1 attrs-22.2.0 blinker-1.5 cachetools-5.3.0 certifi-2022.12.7 charset-normalizer-3.0.1 entrypoints-0.4 gitdb-4.0.10 gitpython-3.1.30 idna-3.4 importlib-metadata-6.0.0 jsonschema-4.17.3 markdown-it-py-2.1.0 mdurl-0.1.2 numpy-1.24.1 pandas-1.5.3 pillow-9.4.0 protobuf-3.20.3 pyarrow-10.0.1 pydeck-0.8.0 pympler-1.0.1 pyrsistent-0.19.3 pytz-2022.7.1 pytz-deprecation-shim-0.1.0.post0 requests-2.28.2 rich-13.2.0 semver-2.13.0 smmap-5.0.0 streamlit-1.17.0 toml-0.10.2 toolz-0.12.0 typing-extensions-4.4.0 tzdata-2022.7 tzlocal-4.2 urllib3-1.26.14 validators-0.20.0 watchdog-2.2.1 zipp-3.11.0
#   DEPRECATION: validators is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559

# %%
import streamlit as st

st.title = "Calculate Area of Rectangle"
length = st.number_input("Input Length", 0)
width = st.number_input("Input Width", 0)

calculate = st.button("Calculate")

if calculate:
    area = length * width
    st.write("Area of Rectangle is", area)
    st.success(f"Area of Rectangle is {area}")
